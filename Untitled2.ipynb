# %%
import gradio as gr

def explain_concept(concept):
    if not concept or not concept.strip():
        return "Please enter a concept you'd like me to explain."

    concept = concept.strip()

    return f


with gr.Blocks(title="StudyMate") as app:
    gr.Markdown("# 📚 StudyMate")

    concept_input = gr.Textbox(
        label="Enter a concept",
        placeholder="Enter any concept...",
        lines=2
    )

    explain_btn = gr.Button("Explain", variant="primary")

    explanation_output = gr.Markdown(value="Enter a concept and I'll explain it!")

    explain_btn.click(explain_concept, inputs=[concept_input], outputs=[explanation_output])
    concept_input.submit(explain_concept, inputs=[concept_input], outputs=[explanation_output])

app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://be67f0ddad7a29cc52.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://be67f0ddad7a29cc52.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
